# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def calculate_loss(prediction, target):
    if target == 1:
        return -np.log(prediction)
    else:
        return -np.log(1 - prediction)

def calculate_activation(z):
    return 1 / (1 + np.exp(-z))

def calculate_loss_derivative(prediction, target):
    if target == 1:
        return -1 / prediction
    else:
        return 1 / (1 - prediction)

def calculate_activation_derivative(x):
    return x * (1 - x)

# Data
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
Y = np.array([0, 0, 0, 1])

# Visualization
X_plot = np.array([[0, 0], [0, 5], [5, 0], [5, 5]])
Y_plot = np.array([0, 0, 0, 1])

area = 200
fig = plt.figure(figsize=(6, 6))
plt.title('The AND Gate', fontsize=20)
ax = fig.add_subplot(111)
ax.scatter(0, 0, s=area, c='r', label="Class 0")
ax.scatter(0, 5, s=area, c='r', label="Class 0")
ax.scatter(5, 0, s=area, c='r', label="Class 0")
ax.scatter(5, 5, s=area, c='b', label="Class 1")
plt.grid()
plt.show()
